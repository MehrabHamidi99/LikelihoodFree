# %%
from torch.distributions import Gamma

import matplotlib.pyplot as plt

# %%
m = Gamma(torch.tensor([1.]), 1 / torch.tensor([0.14]))
a = m.sample(torch.Size([10000]))
# print(a)
plt.plot(a)
plt.show()

a = m.sample(torch.Size([100]))
# print(a)
plt.plot(a)
plt.show()
